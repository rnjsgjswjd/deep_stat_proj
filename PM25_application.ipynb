# %%
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense, Dropout, BatchNormalization
# from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
import numpy as np
import GPy
import matplotlib.pyplot as plt

# %%
## Read PM2.5 data at June 05, 2019
df1 = pd.read_csv('C:\git\DeepKriging\covariate0605.csv')
df2 = pd.read_csv('C:\git\DeepKriging\pm25_0605.csv')

# %%
df1.head(5)
# Out:
#    Unnamed: 0       long        lat      prec        temp          pres  \
# 0       41242 -69.111491  47.386418  0.283942  278.605652  96929.570312
# 1       41243 -68.736976  47.244262  0.276129  278.605652  97242.070312
# 2       41244 -68.364554  47.100850  0.276129  279.753113  98692.070312
# 3       41245 -67.994227  46.956192  0.604254  280.398621  98792.070312
# 4       41589 -69.318835  47.131182  0.174567  278.424988  96567.070312
#
#           rh     uwind     vwind
# 0  79.589600  4.852976  1.651037
# 1  79.589600  4.470163  1.646155
# 2  75.652100  4.477976  1.624670
# 3  77.417725  4.096140  1.615881
# 4  77.456787  5.140085  1.481116

# %%
df2.head(5)
# Out:
#    Unnamed: 0  Longitude   Latitude      PM25  PM_class
# 0           1 -80.482778  25.471944  4.400000         1
# 1           2 -80.215556  25.794222  4.929167         1
# 2           3 -97.493830  25.892518  8.213636         1
# 3           4 -80.326389  25.941944  4.100000         1
# 4           5 -80.256944  26.053889  4.992754         1

# %%
covariates = df1.values[:,3:]
covariates.shape
# Out:
# (7706, 6)

# %%
aqs_lonlat=df2.values[:,[1,2]]
aqs_lonlat.shape
# Out:
# (842, 2)

# %% [markdown]
# ### Pair the long and lat based on the nearest neighbor

# %%
from scipy import spatial
near = df1.values[:,[1,2]]
tree = spatial.KDTree(list(zip(near[:,0].ravel(), near[:,1].ravel())))
tree.data
idx = tree.query(aqs_lonlat)[1]

# %%
df2_new = df2.assign(neighbor = idx)
df_pm25 = df2_new.groupby('neighbor')['PM25'].mean()
df_pm25_class = pd.cut(df_pm25,bins=[-0.1,12.1,35.5],labels=["0","1"])
    # cut 기준을 0부터 해서 오류가 발생함. -0.1부터 시작하면 오류가 발생하지 않음.
idx_new = df_pm25.index.values

# %%
pm25 = df_pm25.values
pm25_class = np.array(df_pm25_class.values, dtype=int)
z = pm25[:,None]
z_class = pm25_class[:,None]

# %%
lon = df1.values[:,1]
lat = df1.values[:,2]
normalized_lon = (lon-min(lon))/(max(lon)-min(lon))
normalized_lat = (lat-min(lat))/(max(lat)-min(lat))
N = lon.shape[0]

# %%
num_basis = [10**2,19**2,37**2]
knots_1dx = [np.linspace(0,1,int(np.sqrt(i))) for i in num_basis]
knots_1dy = [np.linspace(0,1,int(np.sqrt(i))) for i in num_basis]
##Wendland kernel
basis_size = 0
phi = np.zeros((N, sum(num_basis)))
for res in range(len(num_basis)):
    theta = 1/np.sqrt(num_basis[res])*2.5
    knots_x, knots_y = np.meshgrid(knots_1dx[res],knots_1dy[res])
    knots = np.column_stack((knots_x.flatten(),knots_y.flatten()))
    for i in range(num_basis[res]):
        d = np.linalg.norm(np.vstack((normalized_lon,normalized_lat)).T-knots[i,:],axis=1)/theta
        for j in range(len(d)):
            if d[j] >= 0 and d[j] <= 1:
                phi[j,i + basis_size] = (1-d[j])**6 * (35 * d[j]**2 + 18 * d[j] + 3)/3
            else:
                phi[j,i + basis_size] = 0
    basis_size = basis_size + num_basis[res]

# %%
## Romove the all-zero columns
idx_zero = np.array([], dtype=int)
for i in range(phi.shape[1]):
    if sum(phi[:,i]!=0)==0:
        idx_zero = np.append(idx_zero,int(i))

# %%
phi_reduce = np.delete(phi,idx_zero,1)
print(phi.shape)
print(phi_reduce.shape)
# Out:
# (7706, 1830)
# (7706, 1486)

# %%
phi_obs = phi_reduce[idx_new,:]
s_obs = np.vstack((normalized_lon[idx_new],normalized_lat[idx_new])).T
X = covariates[idx_new,:]
normalized_X = X
for i in range(X.shape[1]):
    normalized_X[:,i] = (X[:,i]-min(X[:,i]))/(max(X[:,i])-min(X[:,i]))
N_obs = X.shape[0]

# %%
# scatter plot of the circles dataset with points colored by class
from numpy import where
from matplotlib import pyplot
# select indices of points with each class label
for i in range(2):
	samples_ix = where(z_class[:,0] == i)
	pyplot.scatter(s_obs[samples_ix, 0], s_obs[samples_ix, 1], label=str(i))
pyplot.legend()
pyplot.show()

# %%
## Save the prepocessed data for Kriging
z_log = np.log(z)
kriging = np.concatenate((s_obs, normalized_X, z, z_class,z_log),axis=1)
traindf=pd.DataFrame(kriging)
traindf.to_csv('C:\git\DeepKriging\kriging.csv')
# Out:
#  C:\Users\권헌정\AppData\Local\Temp\ipykernel_22488\3413144608.py:2: RuntimeWarning:divide by zero encountered in log

# %% [markdown]
# ## DeepKriging and baseline DNN performance

# %% [markdown]
# ### Load the useful functions

# %%
def deep_model(model, X_train, y_train, X_valid, y_valid, data_type):
    '''
    Function to train a multi-class model. The number of epochs and 
    batch_size are set by the constants at the top of the
    notebook. 
    
    Parameters:
        model : model with the chosen architecture
        X_train : training features
        y_train : training target
        X_valid : validation features
        Y_valid : validation target
    Output:
        model training history
    '''
    if data_type == 'continuous':
        model.compile(optimizer='adam'
                      , loss='mse'
                      , metrics=['mse','mae'])
    if data_type == 'discrete':
        model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    history = model.fit(X_train
                       , y_train
                       , epochs=NB_START_EPOCHS
                       , batch_size=BATCH_SIZE
                       , validation_data=(X_valid, y_valid)
                       , verbose=0)
    return history

def test_model(model, X_train, y_train, X_test, y_test, epoch_stop):
    '''
    Function to test the model on new data after training it
    on the full training data with the optimal number of epochs.
    
    Parameters:
        model : trained model
        X_train : training features
        y_train : training target
        X_test : test features
        y_test : test target
        epochs : optimal number of epochs
    Output:
        test accuracy and test loss
    '''
    model.fit(X_train
              , y_train
              , epochs=epoch_stop
              , batch_size=BATCH_SIZE
              , verbose=0)
    results = model.evaluate(X_test, y_test, verbose=0)
    return results
    
def optimal_epoch(model_hist):
    '''
    Function to return the epoch number where the validation loss is
    at its minimum
    
    Parameters:
        model_hist : training history of model
    Output:
        epoch number with minimum validation loss
    '''
    min_epoch = np.argmin(model_hist.history['val_loss']) + 1
    return min_epoch

# %% [markdown]
# ### Specify the model structure

# %%
# DeepKriging model for continuous data
p = covariates.shape[1] + phi_reduce.shape[1]
model = Sequential()
model.add(Dense(100, input_dim = p,  kernel_initializer='he_uniform', activation='relu'))
model.add(Dropout(rate=0.5))
model.add(BatchNormalization())
model.add(Dense(100, activation='relu'))
model.add(Dropout(rate=0.5))
model.add(Dense(100, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(1, activation='linear'))

# %%
# DeepKriging model for categorical data
model_class = Sequential()
model_class.add(Dense(100, input_dim = p,  kernel_initializer='he_uniform', activation='relu'))
model_class.add(Dropout(rate=0.5))
model_class.add(BatchNormalization())
model_class.add(Dense(100, activation='relu'))
model_class.add(Dropout(rate=0.5))
model_class.add(Dense(100, activation='relu'))
model_class.add(BatchNormalization())
model_class.add(Dense(1, activation='sigmoid'))

# %%
# Baseline DNN only with covariates and coordinates
p_base = covariates.shape[1] + s_obs.shape[1]
# Neural network
model_base = Sequential()
model_base.add(Dense(100, input_dim=p_base,  kernel_initializer='he_uniform', activation='relu'))
model_base.add(Dropout(rate=0.5))
model_base.add(BatchNormalization())
model_base.add(Dense(100, activation='relu'))
model_base.add(Dropout(rate=0.5))
model_base.add(Dense(100, activation='relu'))
model_base.add(BatchNormalization())
model_base.add(Dense(1, activation='linear'))

# %%
# Baseline DNN for classification
model_base_class = Sequential()
model_base_class.add(Dense(100, input_dim=p_base,  kernel_initializer='he_uniform', activation='relu'))
model_base_class.add(Dropout(rate=0.5))
model_base_class.add(BatchNormalization())
model_base_class.add(Dense(100, activation='relu'))
model_base_class.add(Dropout(rate=0.5))
model_base_class.add(Dense(100, activation='relu'))
model_base_class.add(BatchNormalization())
model_base_class.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# ### Run cross-validation

# %%
from sklearn.model_selection import KFold
NB_START_EPOCHS = 200  # Number of epochs we usually start to train with
BATCH_SIZE = 64  # Size of the batches used in the mini-batch gradient descent

# %%
# 10-fold cross-validation
num_folds = 10
kfold = KFold(n_splits=num_folds, shuffle=True, random_state = 123)
fold_no = 1
inputs = np.hstack((normalized_X,phi_obs))
inputs_base = np.hstack((normalized_X,s_obs))
targets = z
targets_class = z_class
mse_per_fold = []
mse_per_fold_base = []
mae_per_fold = []
mae_per_fold_base = []
acc_per_fold = []
acc_per_fold_base = []
for train_idx, test_idx in kfold.split(inputs, targets):
    print('------------------------------------------------------------------------')
    print(f'Training for fold {fold_no} ...')
    history = deep_model(model, inputs[train_idx], targets[train_idx,0:1]\
                              , inputs[test_idx], targets[test_idx,0:1],'continuous')
    history_base = deep_model(model_base, inputs_base[train_idx], targets[train_idx,0:1]\
                              , inputs_base[test_idx], targets[test_idx,0:1],'continuous')
    ## Classification
    history_class = deep_model(model_class, inputs[train_idx], targets_class[train_idx,0:1]\
                              , inputs[test_idx], targets_class[test_idx,0:1],'discrete')
    history_base_class = deep_model(model_base_class, inputs_base[train_idx], targets_class[train_idx,0:1]\
                              , inputs_base[test_idx], targets_class[test_idx,0:1],'discrete')
    model_optim = 200 #optimal_epoch(history)
    model_optim_base = 200 #optimal_epoch(history_base)
    result = test_model(model, inputs[train_idx], targets[train_idx,0:1], inputs[test_idx]\
                        , targets[test_idx,0:1], model_optim)
    result_base = test_model(model_base, inputs_base[train_idx], targets[train_idx,0:1], inputs_base[test_idx]\
                             , targets[test_idx,0:1], model_optim_base)
    scores = result
    scores_base = result_base
    print(f'The performance of DeepKriging: MSE = {scores[1]}, MAE = {scores[2]}')
    print(f'The performance of classical DNN: MSE = {scores_base[1]}, MAE = {scores_base[2]}')
    model_optim_class = 200 #optimal_epoch(history_class)
    model_optim_base_class = 200 #optimal_epoch(history_base_class)
    result_class = test_model(model_class, inputs[train_idx], targets_class[train_idx,0:1], inputs[test_idx]\
                        , targets_class[test_idx,0:1], model_optim_class)
    result_base_class = test_model(model_base_class, inputs_base[train_idx], targets_class[train_idx,0:1], inputs_base[test_idx]\
                             , targets_class[test_idx,0:1], model_optim_base_class)
    scores_class = result_class
    scores_base_class = result_base_class
    print(f'The performance of DeepKriging: accuracy = {scores_class[1]}')
    print(f'The performance of classical DNN: accuracy = {result_base_class[1]}')
    fold_no = fold_no + 1
    acc_per_fold.append(scores_class[1])
    acc_per_fold_base.append(scores_base_class[1])
    mse_per_fold.append(scores[1])
    mse_per_fold_base.append(scores_base[1])
    mae_per_fold.append(scores[2])
    mae_per_fold_base.append(scores_base[2])
# Out:
# ------------------------------------------------------------------------
# Training for fold 1 ...
# The performance of DeepKriging: MSE = 6.364070892333984, MAE = 1.868182897567749
# The performance of classical DNN: MSE = 5.266538143157959, MAE = 1.7143360376358032
# The performance of DeepKriging: accuracy = 0.868852436542511
# The performance of classical DNN: accuracy = 0.8852459192276001
# ------------------------------------------------------------------------
# Training for fold 2 ...
# The performance of DeepKriging: MSE = 3.2346861362457275, MAE = 1.3234796524047852
# The performance of classical DNN: MSE = 3.5677695274353027, MAE = 1.535520076751709
# The performance of DeepKriging: accuracy = 0.9344262480735779
# The performance of classical DNN: accuracy = 0.9344262480735779
# ------------------------------------------------------------------------
# Training for fold 3 ...
# The performance of DeepKriging: MSE = 1.826218605041504, MAE = 0.9898558259010315
# The performance of classical DNN: MSE = 5.0409321784973145, MAE = 1.8050038814544678
# The performance of DeepKriging: accuracy = 0.868852436542511
# The performance of classical DNN: accuracy = 0.8032786846160889
# ------------------------------------------------------------------------
# Training for fold 4 ...
# The performance of DeepKriging: MSE = 2.463526487350464, MAE = 1.058786153793335
# The performance of classical DNN: MSE = 4.265161037445068, MAE = 1.5293214321136475
# The performance of DeepKriging: accuracy = 0.9344262480735779
# The performance of classical DNN: accuracy = 0.9508196711540222
# ------------------------------------------------------------------------
# Training for fold 5 ...
# The performance of DeepKriging: MSE = 2.1008996963500977, MAE = 1.0174411535263062
# The performance of classical DNN: MSE = 4.21993350982666, MAE = 1.4824421405792236
# The performance of DeepKriging: accuracy = 0.9508196711540222
# The performance of classical DNN: accuracy = 0.9344262480735779
# ------------------------------------------------------------------------
# Training for fold 6 ...
# The performance of DeepKriging: MSE = 1.3730441331863403, MAE = 0.8207285404205322
# The performance of classical DNN: MSE = 2.428429365158081, MAE = 1.1531810760498047
# The performance of DeepKriging: accuracy = 0.9333333373069763
# The performance of classical DNN: accuracy = 0.8999999761581421
# ------------------------------------------------------------------------
# Training for fold 7 ...
# The performance of DeepKriging: MSE = 0.6456621885299683, MAE = 0.6561817526817322
# The performance of classical DNN: MSE = 2.6498818397521973, MAE = 1.2064107656478882
# The performance of DeepKriging: accuracy = 0.9666666388511658
# The performance of classical DNN: accuracy = 0.9166666865348816
# ------------------------------------------------------------------------
# Training for fold 8 ...
# The performance of DeepKriging: MSE = 1.2243586778640747, MAE = 0.739517092704773
# The performance of classical DNN: MSE = 2.6987664699554443, MAE = 1.2172935009002686
# The performance of DeepKriging: accuracy = 0.9333333373069763
# The performance of classical DNN: accuracy = 0.8666666746139526
# ------------------------------------------------------------------------
# Training for fold 9 ...
# The performance of DeepKriging: MSE = 1.6243510246276855, MAE = 0.8183917999267578
# The performance of classical DNN: MSE = 5.05859899520874, MAE = 1.738641619682312
# The performance of DeepKriging: accuracy = 0.9333333373069763
# The performance of classical DNN: accuracy = 0.8833333253860474
# ------------------------------------------------------------------------
# Training for fold 10 ...
# The performance of DeepKriging: MSE = 0.5713004469871521, MAE = 0.5994537472724915
# The performance of classical DNN: MSE = 2.41560435295105, MAE = 1.1823769807815552
# The performance of DeepKriging: accuracy = 0.949999988079071
# The performance of classical DNN: accuracy = 0.9833333492279053

# %%
##Summerize the results with meassage
print(np.mean(mse_per_fold))
print(np.std(mse_per_fold))
print(np.mean(mse_per_fold_base))
print(np.std(mse_per_fold_base))
print(np.mean(mae_per_fold))
print(np.std(mae_per_fold))
print(np.mean(mae_per_fold_base))
print(np.std(mae_per_fold_base))
print(np.mean(acc_per_fold))
print(np.std(acc_per_fold))
print(np.mean(acc_per_fold_base))
print(np.std(acc_per_fold_base))
# Out:
# 2.1428118288516997
# 1.6010018283180951
# 3.761161541938782
# 1.0972478429888513
# 0.9892018616199494
# 0.35674878675564153
# 1.4564527511596679
# 0.2380480100168591
# 0.9274043679237366
# 0.031082299410456087
# 0.9058196783065796
# 0.047747351172325626

# %%
## Save the same test index for Kriging
train_idx_combine = []
test_idx_combine = []
for train_idx, test_idx in kfold.split(inputs, targets):
    train_idx_combine.append(train_idx)
    test_idx_combine.append(test_idx)  
test_df = pd.DataFrame(test_idx_combine).T
test_df.to_csv('C:\git\DeepKriging/test_idx.csv')

# %% [markdown]
# ### The case without covariates

# %%
# DeepKriging model for continuous data
p2 =  phi_reduce.shape[1]
model_nx = Sequential()
model_nx.add(Dense(100, input_dim = p2,  kernel_initializer='he_uniform', activation='relu'))
model_nx.add(Dropout(rate=0.5))
model_nx.add(BatchNormalization())
model_nx.add(Dense(100, activation='relu'))
model_nx.add(Dropout(rate=0.5))
model_nx.add(Dense(100, activation='relu'))
model_nx.add(BatchNormalization())
model_nx.add(Dense(1, activation='linear'))

# %%
# DeepKriging model for categorical data
model_class_nx = Sequential()
model_class_nx.add(Dense(100, input_dim = p2,  kernel_initializer='he_uniform', activation='relu'))
model_class_nx.add(Dropout(rate=0.5))
model_class_nx.add(BatchNormalization())
model_class_nx.add(Dense(100, activation='relu'))
model_class_nx.add(Dropout(rate=0.5))
model_class_nx.add(Dense(100, activation='relu'))
model_class_nx.add(BatchNormalization())
model_class_nx.add(Dense(1, activation='sigmoid'))

# %%
inputs = phi_obs
inputs_base = s_obs
targets = z
targets_class = z_class
mse_per_fold_nx = []
mae_per_fold_nx = []
acc_per_fold_nx = []
fold_no = 1
for train_idx, test_idx in kfold.split(inputs, targets):
    print('------------------------------------------------------------------------')
    print(f'Training for fold {fold_no} ...')
    history_nx = deep_model(model_nx, inputs[train_idx], targets[train_idx,0:1]\
                              , inputs[test_idx], targets[test_idx,0:1],'continuous')
    ## Classification
    history_class_nx = deep_model(model_class_nx, inputs[train_idx], targets_class[train_idx,0:1]\
                              , inputs[test_idx], targets_class[test_idx,0:1],'discrete')
    model_optim_nx = 200#optimal_epoch(history_nx)
    result_nx = test_model(model_nx, inputs[train_idx], targets[train_idx,0:1], inputs[test_idx]\
                        , targets[test_idx,0:1], model_optim_nx)
    scores_nx = result_nx
    print(f'The performance of DeepKriging without X: MSE = {scores_nx[1]}, MAE = {scores_nx[2]}')
    model_optim_class_nx = 200#optimal_epoch(history_class_nx)
    result_class_nx = test_model(model_class_nx, inputs[train_idx], targets_class[train_idx,0:1], inputs[test_idx]\
                        , targets_class[test_idx,0:1], model_optim_class_nx)
    scores_class_nx = result_class_nx
    print(f'The performance of DeepKriging without X: accuracy = {scores_class_nx[1]}')
    fold_no = fold_no + 1
    acc_per_fold_nx.append(scores_class_nx[1])
    mse_per_fold_nx.append(scores_nx[1])
    mae_per_fold_nx.append(scores_nx[2])
# Out:
# ------------------------------------------------------------------------
# Training for fold 1 ...
# The performance of DeepKriging without X: MSE = 6.65176248550415, MAE = 1.9349738359451294
# The performance of DeepKriging without X: accuracy = 0.868852436542511
# ------------------------------------------------------------------------
# Training for fold 2 ...
# The performance of DeepKriging without X: MSE = 3.706620931625366, MAE = 1.4088797569274902
# The performance of DeepKriging without X: accuracy = 0.9016393423080444
# ------------------------------------------------------------------------
# Training for fold 3 ...
# The performance of DeepKriging without X: MSE = 2.630722999572754, MAE = 1.1468505859375
# The performance of DeepKriging without X: accuracy = 0.8852459192276001
# ------------------------------------------------------------------------
# Training for fold 4 ...
# The performance of DeepKriging without X: MSE = 2.5812623500823975, MAE = 1.1907891035079956
# The performance of DeepKriging without X: accuracy = 0.9344262480735779
# ------------------------------------------------------------------------
# Training for fold 5 ...
# The performance of DeepKriging without X: MSE = 1.9072771072387695, MAE = 1.0664143562316895
# The performance of DeepKriging without X: accuracy = 0.9672130942344666
# ------------------------------------------------------------------------
# Training for fold 6 ...
# The performance of DeepKriging without X: MSE = 1.444950819015503, MAE = 0.8865647912025452
# The performance of DeepKriging without X: accuracy = 0.949999988079071
# ------------------------------------------------------------------------
# Training for fold 7 ...
# The performance of DeepKriging without X: MSE = 0.8131355047225952, MAE = 0.7329280972480774
# The performance of DeepKriging without X: accuracy = 0.9333333373069763
# ------------------------------------------------------------------------
# Training for fold 8 ...
# The performance of DeepKriging without X: MSE = 2.1013078689575195, MAE = 1.0009400844573975
# The performance of DeepKriging without X: accuracy = 0.949999988079071
# ------------------------------------------------------------------------
# Training for fold 9 ...
# The performance of DeepKriging without X: MSE = 2.562314033508301, MAE = 1.0436012744903564
# The performance of DeepKriging without X: accuracy = 0.949999988079071
# ------------------------------------------------------------------------
# Training for fold 10 ...
# The performance of DeepKriging without X: MSE = 0.6267536878585815, MAE = 0.5855730772018433
# The performance of DeepKriging without X: accuracy = 0.9666666388511658

# %%
print(np.mean(mse_per_fold_nx))
print(np.std(mse_per_fold_nx))
print(np.mean(mae_per_fold_nx))
print(np.std(mae_per_fold_nx))
print(np.mean(acc_per_fold_nx))
print(np.std(acc_per_fold_nx))
# Out:
# 2.502610778808594
# 1.6339688169172595
# 1.0997514963150024
# 0.3552573911613704
# 0.9307376980781555
# 0.032404930718935764

# %% [markdown]
# ## Prediction

# %%
covariates
# Out:
# array([[ 2.83941597e-01,  2.78605652e+02,  9.69295703e+04,
#          7.95895996e+01,  4.85297585e+00,  1.65103745e+00],
#        [ 2.76129097e-01,  2.78605652e+02,  9.72420703e+04,
#          7.95895996e+01,  4.47016335e+00,  1.64615464e+00],
#        [ 2.76129097e-01,  2.79753113e+02,  9.86920703e+04,
#          7.56520996e+01,  4.47797585e+00,  1.62467027e+00],
#        ...,
#        [ 3.93316597e-01,  2.93506042e+02,  1.00979570e+05,
#          7.11989822e+01,  1.48481190e+00, -3.00521255e+00],
#        [ 2.06519151e+00,  2.92847839e+02,  1.01029570e+05,
#          7.33864746e+01,  1.86274159e+00, -2.99056411e+00],
#        [ 8.73706627e+00,  2.92403503e+02,  1.01292070e+05,
#          7.79099121e+01,  1.79731190e+00, -3.06185317e+00]])

# %%
inputs = np.hstack((normalized_X,phi_obs))
targets = z
history = deep_model(model, inputs, targets[:,0:1], inputs, targets[:,0:1],'continuous')

# %%
X_pred = covariates
normalized_X_pred = X_pred
for i in range(X_pred.shape[1]):
    normalized_X_pred[:,i] = (X_pred[:,i]-min(X[:,i]))/(max(X[:,i])-min(X[:,i]))

# %%
X_RBF_pred = np.hstack((normalized_X_pred,phi_reduce))
PM25_pred = model.predict(X_RBF_pred)
# Out:
# 241/241 [==============================] - 0s 2ms/step

# %%
s = np.vstack((normalized_lon,normalized_lat)).T
PM25_pred_combine = np.concatenate((s,normalized_X_pred,PM25_pred),axis=1)
PM25_pred_df=pd.DataFrame(PM25_pred_combine)
PM25_pred_df.to_csv('C:\git\DeepKriging\PM25_pred_0605.csv')

# %% [markdown]
# ### Risk

# %%
import sys
sys.path.append('../')
from dcdr.deep_hist import Binning_CDF
from scipy.stats import iqr
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
import matplotlib;matplotlib.rcParams['figure.figsize'] = (8,6)
init_seed=1
num_cut = int((max(z)-min(z))*N**(1/3)/(2*iqr(z)))
hidden_list = [100,100,100]
dropout_list = [0.5,0.5,0.5]
histogram_bin = 'random'
loss_model = 'multi-binary'
seeding = 1

# %%
import tensorflow as tf

# GPU 설정
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # 첫 번째 GPU만 사용하도록 설정
        tf.config.experimental.set_visible_devices(gpus[0], 'GPU')
        
        # GPU 메모리 할당을 동적으로 조정
        tf.config.experimental.set_memory_growth(gpus[0], True)
    except RuntimeError as e:
        print(e)

# %%
dcdr_model = Binning_CDF(num_cut=num_cut, hidden_list=hidden_list,
                         histogram_bin=histogram_bin, dropout_list=dropout_list,
                         seeding=seeding, loss_model=loss_model, 
                         niter=10)
    
dcdr_model.fit_cdf(inputs, targets, batch_size=32, merge_empty_bin=True)
# Out:
# Epoch 1/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.5353 - accuracy: 0.0208 WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 1s 14ms/step - loss: 0.5352 - accuracy: 0.0207 - val_loss: 0.7956 - val_accuracy: 0.0083 - lr: 0.0010
# Epoch 2/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4951 - accuracy: 0.0208WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4950 - accuracy: 0.0207 - val_loss: 0.7441 - val_accuracy: 0.0083 - lr: 0.0010
# Epoch 3/500
#  8/16 [==============>...............] - ETA: 0s - loss: 0.4857 - accuracy: 0.0273
#  c:\git\DeepKriging\dcdr\early_stopping_callback.py:95: RuntimeWarning:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4762 - accuracy: 0.0208WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 11ms/step - loss: 0.4754 - accuracy: 0.0207 - val_loss: 0.6703 - val_accuracy: 0.0083 - lr: 0.0010
# Epoch 4/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4213 - accuracy: 0.0208WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4215 - accuracy: 0.0207 - val_loss: 0.6086 - val_accuracy: 0.0165 - lr: 0.0010
# Epoch 5/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3941 - accuracy: 0.0188WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3943 - accuracy: 0.0207 - val_loss: 0.5900 - val_accuracy: 0.0083 - lr: 0.0010
# Epoch 6/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3737 - accuracy: 0.0188WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3773 - accuracy: 0.0207 - val_loss: 0.5751 - val_accuracy: 0.0083 - lr: 0.0010
# Epoch 7/500
# 16/16 [==============================] - ETA: 0s - loss: 0.3623 - accuracy: 0.0207WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3623 - accuracy: 0.0207 - val_loss: 0.5642 - val_accuracy: 0.0165 - lr: 0.0010
# Epoch 8/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3203 - accuracy: 0.0208WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3211 - accuracy: 0.0207 - val_loss: 0.5478 - val_accuracy: 0.0083 - lr: 0.0010
# Epoch 9/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3057 - accuracy: 0.0208WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.3055 - accuracy: 0.0207 - val_loss: 0.5476 - val_accuracy: 0.0083 - lr: 0.0010
# Epoch 10/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2878 - accuracy: 0.0208    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.2875 - accuracy: 0.0207 - val_loss: 0.5280 - val_accuracy: 0.0083 - lr: 0.0010
# Epoch 11/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2692 - accuracy: 0.0208    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.2696 - accuracy: 0.0207 - val_loss: 0.5063 - val_accuracy: 0.0165 - lr: 0.0010
# Epoch 12/500
# 16/16 [==============================] - ETA: 0s - loss: 0.2714 - accuracy: 0.0207WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.2714 - accuracy: 0.0207 - val_loss: 0.4804 - val_accuracy: 0.0165 - lr: 0.0010
# Epoch 13/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2549 - accuracy: 0.0208    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.2547 - accuracy: 0.0207 - val_loss: 0.4235 - val_accuracy: 0.0165 - lr: 0.0010
# Epoch 14/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2453 - accuracy: 0.0208    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.2451 - accuracy: 0.0207 - val_loss: 0.4218 - val_accuracy: 0.0165 - lr: 0.0010
# Epoch 15/500
# 16/16 [==============================] - ETA: 0s - loss: 0.2420 - accuracy: 0.0207    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.2420 - accuracy: 0.0207 - val_loss: 0.4652 - val_accuracy: 0.0165 - lr: 0.0010
# Epoch 16/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2477 - accuracy: 0.0208    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.2469 - accuracy: 0.0207 - val_loss: 0.4653 - val_accuracy: 0.0165 - lr: 0.0010
# Epoch 17/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2223 - accuracy: 0.0208WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.2240 - accuracy: 0.0207 - val_loss: 0.4661 - val_accuracy: 0.0083 - lr: 0.0010
# Epoch 18/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2216 - accuracy: 0.0208    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.2213 - accuracy: 0.0207 - val_loss: 0.3882 - val_accuracy: 0.0083 - lr: 0.0010
# Epoch 19/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2157 - accuracy: 0.0208    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.2148 - accuracy: 0.0207 - val_loss: 0.4094 - val_accuracy: 0.0083 - lr: 0.0010
# Epoch 20/500
# 16/16 [==============================] - ETA: 0s - loss: 0.2177 - accuracy: 0.0207WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.2177 - accuracy: 0.0207 - val_loss: 0.4637 - val_accuracy: 0.0248 - lr: 0.0010
# Epoch 21/500
# 16/16 [==============================] - ETA: 0s - loss: 0.2181 - accuracy: 0.0207    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.2181 - accuracy: 0.0207 - val_loss: 0.4473 - val_accuracy: 0.0165 - lr: 0.0010
# Epoch 22/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2046 - accuracy: 0.0208WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.2054 - accuracy: 0.0207 - val_loss: 0.4364 - val_accuracy: 0.0165 - lr: 0.0010
# Epoch 23/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1981 - accuracy: 0.0208WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1984 - accuracy: 0.0207 - val_loss: 0.4473 - val_accuracy: 0.0165 - lr: 0.0010
# Epoch 24/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1922 - accuracy: 0.0208WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1919 - accuracy: 0.0207 - val_loss: 0.4478 - val_accuracy: 0.0248 - lr: 0.0010
# Epoch 25/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1799 - accuracy: 0.0208    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1810 - accuracy: 0.0207 - val_loss: 0.4454 - val_accuracy: 0.0165 - lr: 0.0010
# Epoch 26/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1961 - accuracy: 0.0208WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.2021 - accuracy: 0.0207 - val_loss: 0.3922 - val_accuracy: 0.0165 - lr: 0.0010
# Epoch 27/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1849 - accuracy: 0.0208WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1844 - accuracy: 0.0207 - val_loss: 0.3941 - val_accuracy: 0.0165 - lr: 0.0010
# Epoch 28/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1833 - accuracy: 0.0208WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1833 - accuracy: 0.0207 - val_loss: 0.4073 - val_accuracy: 0.0165 - lr: 0.0010
# Epoch 29/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1813 - accuracy: 0.0208WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1805 - accuracy: 0.0207 - val_loss: 0.4100 - val_accuracy: 0.0165 - lr: 0.0010
# Epoch 30/500
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1774 - accuracy: 0.0216WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1766 - accuracy: 0.0207 - val_loss: 0.4090 - val_accuracy: 0.0165 - lr: 0.0010
# Epoch 31/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1776 - accuracy: 0.0208    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1770 - accuracy: 0.0207 - val_loss: 0.4184 - val_accuracy: 0.0165 - lr: 0.0010
# Epoch 32/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1665 - accuracy: 0.0208WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1667 - accuracy: 0.0207 - val_loss: 0.4734 - val_accuracy: 0.0165 - lr: 0.0010
# Epoch 33/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1606 - accuracy: 0.0208WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1600 - accuracy: 0.0207 - val_loss: 0.4693 - val_accuracy: 0.0165 - lr: 0.0010
# Epoch 34/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1627 - accuracy: 0.0208WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1629 - accuracy: 0.0207 - val_loss: 0.4728 - val_accuracy: 0.0165 - lr: 0.0010
# Epoch 35/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1643 - accuracy: 0.0208WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1638 - accuracy: 0.0207 - val_loss: 0.4647 - val_accuracy: 0.0248 - lr: 0.0010
# Epoch 36/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1551 - accuracy: 0.0208    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1546 - accuracy: 0.0207 - val_loss: 0.4260 - val_accuracy: 0.0248 - lr: 0.0010
# Epoch 37/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1618 - accuracy: 0.0208    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1624 - accuracy: 0.0207 - val_loss: 0.3439 - val_accuracy: 0.0248 - lr: 0.0010
# Epoch 38/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1410 - accuracy: 0.0208WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1413 - accuracy: 0.0207 - val_loss: 0.3396 - val_accuracy: 0.0248 - lr: 0.0010
# Epoch 39/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1572 - accuracy: 0.0208WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1617 - accuracy: 0.0207 - val_loss: 0.3486 - val_accuracy: 0.0248 - lr: 0.0010
# Epoch 40/500
# 16/16 [==============================] - ETA: 0s - loss: 0.1490 - accuracy: 0.0207WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1490 - accuracy: 0.0207 - val_loss: 0.3549 - val_accuracy: 0.0248 - lr: 0.0010
# Epoch 41/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1538 - accuracy: 0.0208WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1534 - accuracy: 0.0207 - val_loss: 0.3558 - val_accuracy: 0.0248 - lr: 0.0010
# Epoch 42/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1496 - accuracy: 0.0208    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1501 - accuracy: 0.0207 - val_loss: 0.3570 - val_accuracy: 0.0248 - lr: 0.0010
# Epoch 43/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1453 - accuracy: 0.0188WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1487 - accuracy: 0.0207 - val_loss: 0.3403 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 44/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1504 - accuracy: 0.0208WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1501 - accuracy: 0.0207 - val_loss: 0.3405 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 45/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1358 - accuracy: 0.0208    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1363 - accuracy: 0.0207 - val_loss: 0.3179 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 46/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1422 - accuracy: 0.0208WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1431 - accuracy: 0.0207 - val_loss: 0.4020 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 47/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1378 - accuracy: 0.0188WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1379 - accuracy: 0.0207 - val_loss: 0.4039 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 48/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1349 - accuracy: 0.0208    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1354 - accuracy: 0.0207 - val_loss: 0.3975 - val_accuracy: 0.0413 - lr: 0.0010
# Epoch 49/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1323 - accuracy: 0.0208    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1340 - accuracy: 0.0207 - val_loss: 0.3922 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 50/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1322 - accuracy: 0.0208    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1318 - accuracy: 0.0207 - val_loss: 0.3843 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 51/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1437 - accuracy: 0.0208WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1439 - accuracy: 0.0207 - val_loss: 0.3306 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 52/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1400 - accuracy: 0.0208    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1405 - accuracy: 0.0207 - val_loss: 0.3340 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 53/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1241 - accuracy: 0.0208WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1238 - accuracy: 0.0207 - val_loss: 0.3318 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 54/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1264 - accuracy: 0.0208    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1276 - accuracy: 0.0207 - val_loss: 0.3316 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 55/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1283 - accuracy: 0.0208    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1288 - accuracy: 0.0207 - val_loss: 0.3284 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 56/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1261 - accuracy: 0.0208WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1264 - accuracy: 0.0207 - val_loss: 0.3253 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 57/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1287 - accuracy: 0.0208WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1282 - accuracy: 0.0207 - val_loss: 0.3209 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 58/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1148 - accuracy: 0.0208    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1162 - accuracy: 0.0207 - val_loss: 0.3918 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 59/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1321 - accuracy: 0.0208WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1359 - accuracy: 0.0207 - val_loss: 0.4553 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 60/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1258 - accuracy: 0.0208WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1277 - accuracy: 0.0207 - val_loss: 0.4534 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 61/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1160 - accuracy: 0.0208WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1159 - accuracy: 0.0207 - val_loss: 0.4571 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 62/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1116 - accuracy: 0.0188    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1125 - accuracy: 0.0207 - val_loss: 0.4628 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 63/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1174 - accuracy: 0.0208WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1173 - accuracy: 0.0207 - val_loss: 0.4661 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 64/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1178 - accuracy: 0.0208    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1202 - accuracy: 0.0207 - val_loss: 0.4663 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 65/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1197 - accuracy: 0.0208WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1193 - accuracy: 0.0207 - val_loss: 0.3932 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 66/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1263 - accuracy: 0.0188WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1269 - accuracy: 0.0207 - val_loss: 0.4084 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 67/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1145 - accuracy: 0.0208    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1167 - accuracy: 0.0207 - val_loss: 0.4183 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 68/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1225 - accuracy: 0.0208    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1221 - accuracy: 0.0207 - val_loss: 0.4138 - val_accuracy: 0.0413 - lr: 0.0010
# Epoch 69/500
# 13/16 [=======================>......] - ETA: 0s - loss: 0.1204 - accuracy: 0.0192WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1189 - accuracy: 0.0207 - val_loss: 0.4159 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 70/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1207 - accuracy: 0.0188    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1201 - accuracy: 0.0207 - val_loss: 0.4148 - val_accuracy: 0.0413 - lr: 0.0010
# Epoch 71/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1131 - accuracy: 0.0208WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1138 - accuracy: 0.0207 - val_loss: 0.4228 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 72/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1115 - accuracy: 0.0208WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1163 - accuracy: 0.0207 - val_loss: 0.4714 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 73/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1113 - accuracy: 0.0208WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1123 - accuracy: 0.0207 - val_loss: 0.4710 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 74/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1182 - accuracy: 0.0208    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1176 - accuracy: 0.0207 - val_loss: 0.4725 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 75/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1152 - accuracy: 0.0188    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1153 - accuracy: 0.0207 - val_loss: 0.4669 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 76/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1100 - accuracy: 0.0208WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1096 - accuracy: 0.0207 - val_loss: 0.4714 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 77/500
# 16/16 [==============================] - ETA: 0s - loss: 0.1101 - accuracy: 0.0207    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1101 - accuracy: 0.0207 - val_loss: 0.4732 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 78/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1145 - accuracy: 0.0208    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1142 - accuracy: 0.0207 - val_loss: 0.4735 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 79/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0947 - accuracy: 0.0208    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1002 - accuracy: 0.0207 - val_loss: 0.4755 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 80/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1060 - accuracy: 0.0208    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1060 - accuracy: 0.0207 - val_loss: 0.4690 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 81/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1149 - accuracy: 0.0188WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1144 - accuracy: 0.0207 - val_loss: 0.4721 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 82/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1150 - accuracy: 0.0208WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1151 - accuracy: 0.0207 - val_loss: 0.4713 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 83/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1146 - accuracy: 0.0208    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1141 - accuracy: 0.0207 - val_loss: 0.4682 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 84/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1002 - accuracy: 0.0208WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1002 - accuracy: 0.0207 - val_loss: 0.4728 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 85/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1019 - accuracy: 0.0208WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1027 - accuracy: 0.0207 - val_loss: 0.4709 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 86/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1050 - accuracy: 0.0208WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1047 - accuracy: 0.0207 - val_loss: 0.4714 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 87/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0981 - accuracy: 0.0208WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0982 - accuracy: 0.0207 - val_loss: 0.4711 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 88/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0988 - accuracy: 0.0208    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0990 - accuracy: 0.0207 - val_loss: 0.4746 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 89/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0995 - accuracy: 0.0208    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0995 - accuracy: 0.0207 - val_loss: 0.4765 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 90/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1007 - accuracy: 0.0208    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1026 - accuracy: 0.0207 - val_loss: 0.4833 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 91/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0912 - accuracy: 0.0208WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0927 - accuracy: 0.0207 - val_loss: 0.4637 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 92/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0986 - accuracy: 0.0208    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0980 - accuracy: 0.0207 - val_loss: 0.4686 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 93/500
# 14/16 [=========================>....] - ETA: 0s - loss: 0.0996 - accuracy: 0.0156WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 6ms/step - loss: 0.1028 - accuracy: 0.0207 - val_loss: 0.4703 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 94/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1066 - accuracy: 0.0208WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1080 - accuracy: 0.0207 - val_loss: 0.4628 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 95/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0989 - accuracy: 0.0208    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0984 - accuracy: 0.0207 - val_loss: 0.4873 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 96/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0967 - accuracy: 0.0208    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0966 - accuracy: 0.0207 - val_loss: 0.4856 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 97/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0928 - accuracy: 0.0208WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0939 - accuracy: 0.0207 - val_loss: 0.4841 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 98/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1034 - accuracy: 0.0208WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1030 - accuracy: 0.0207 - val_loss: 0.4524 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 99/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0906 - accuracy: 0.0208WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0970 - accuracy: 0.0207 - val_loss: 0.4905 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 100/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0973 - accuracy: 0.0208WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0971 - accuracy: 0.0207 - val_loss: 0.4969 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 101/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0982 - accuracy: 0.0208WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0999 - accuracy: 0.0207 - val_loss: 0.5021 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 102/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0990 - accuracy: 0.0208    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1012 - accuracy: 0.0207 - val_loss: 0.5023 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 103/500
# 16/16 [==============================] - ETA: 0s - loss: 0.0924 - accuracy: 0.0207    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0924 - accuracy: 0.0207 - val_loss: 0.4985 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 104/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0929 - accuracy: 0.0208    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0934 - accuracy: 0.0207 - val_loss: 0.4947 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 105/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0968 - accuracy: 0.0208    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0972 - accuracy: 0.0207 - val_loss: 0.4848 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 106/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0896 - accuracy: 0.0208WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0915 - accuracy: 0.0207 - val_loss: 0.4793 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 107/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0962 - accuracy: 0.0208WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1002 - accuracy: 0.0207 - val_loss: 0.4766 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 108/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.1000 - accuracy: 0.0208WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1002 - accuracy: 0.0207 - val_loss: 0.4760 - val_accuracy: 0.0413 - lr: 0.0010
# Epoch 109/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0904 - accuracy: 0.0208WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0902 - accuracy: 0.0207 - val_loss: 0.4783 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 110/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0912 - accuracy: 0.0208    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0909 - accuracy: 0.0207 - val_loss: 0.4791 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 111/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0935 - accuracy: 0.0188WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0937 - accuracy: 0.0207 - val_loss: 0.4788 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 112/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0953 - accuracy: 0.0208WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0953 - accuracy: 0.0207 - val_loss: 0.4753 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 113/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0911 - accuracy: 0.0208    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0912 - accuracy: 0.0207 - val_loss: 0.4429 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 114/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0996 - accuracy: 0.0208    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0998 - accuracy: 0.0207 - val_loss: 0.4531 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 115/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0892 - accuracy: 0.0208    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0914 - accuracy: 0.0207 - val_loss: 0.4375 - val_accuracy: 0.0413 - lr: 0.0010
# Epoch 116/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0856 - accuracy: 0.0188    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0871 - accuracy: 0.0207 - val_loss: 0.4734 - val_accuracy: 0.0331 - lr: 0.0010
# Epoch 117/500
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0825 - accuracy: 0.0168WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0836 - accuracy: 0.0207 - val_loss: 0.4364 - val_accuracy: 0.0413 - lr: 0.0010
# Epoch 118/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.0847 - accuracy: 0.0208WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 5ms/step - loss: 0.0856 - accuracy: 0.0207 - val_loss: 0.4400 - val_accuracy: 0.0413 - lr: 0.0010
# Epoch 119/500
# ...
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0445 - accuracy: 0.0103 - val_loss: 0.5610 - val_accuracy: 0.0579 - lr: 0.0010
# Epoch 462/500
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0423 - accuracy: 0.0120WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0449 - accuracy: 0.0103 - val_loss: 0.5592 - val_accuracy: 0.0579 - lr: 0.0010
# Epoch 463/500
# 11/16 [===================>..........] - ETA: 0s - loss: 0.0405 - accuracy: 0.0170    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 8ms/step - loss: 0.0415 - accuracy: 0.0145 - val_loss: 0.5544 - val_accuracy: 0.0579 - lr: 0.0010
# Epoch 464/500
# 11/16 [===================>..........] - ETA: 0s - loss: 0.0427 - accuracy: 0.0085    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0454 - accuracy: 0.0103 - val_loss: 0.5519 - val_accuracy: 0.0496 - lr: 0.0010
# Epoch 465/500
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0446 - accuracy: 0.0072    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0484 - accuracy: 0.0103 - val_loss: 0.5642 - val_accuracy: 0.0579 - lr: 0.0010
# Epoch 466/500
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0353 - accuracy: 0.0144WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0376 - accuracy: 0.0145 - val_loss: 0.5659 - val_accuracy: 0.0579 - lr: 0.0010
# Epoch 467/500
# 12/16 [=====================>........] - ETA: 0s - loss: 0.0426 - accuracy: 0.0104    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0406 - accuracy: 0.0124 - val_loss: 0.5675 - val_accuracy: 0.0496 - lr: 0.0010
# Epoch 468/500
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0403 - accuracy: 0.0096WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0446 - accuracy: 0.0103 - val_loss: 0.5651 - val_accuracy: 0.0496 - lr: 0.0010
# Epoch 469/500
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0422 - accuracy: 0.0168    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0410 - accuracy: 0.0145 - val_loss: 0.5521 - val_accuracy: 0.0496 - lr: 0.0010
# Epoch 470/500
# 11/16 [===================>..........] - ETA: 0s - loss: 0.0389 - accuracy: 0.0170    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0440 - accuracy: 0.0124 - val_loss: 0.5471 - val_accuracy: 0.0496 - lr: 0.0010
# Epoch 471/500
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0395 - accuracy: 0.0096    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0444 - accuracy: 0.0124 - val_loss: 0.5933 - val_accuracy: 0.0496 - lr: 0.0010
# Epoch 472/500
# 11/16 [===================>..........] - ETA: 0s - loss: 0.0417 - accuracy: 0.0114    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0410 - accuracy: 0.0145 - val_loss: 0.5949 - val_accuracy: 0.0496 - lr: 0.0010
# Epoch 473/500
# 12/16 [=====================>........] - ETA: 0s - loss: 0.0444 - accuracy: 0.0104WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0422 - accuracy: 0.0103 - val_loss: 0.5998 - val_accuracy: 0.0496 - lr: 0.0010
# Epoch 474/500
# 12/16 [=====================>........] - ETA: 0s - loss: 0.0404 - accuracy: 0.0130WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0400 - accuracy: 0.0103 - val_loss: 0.6032 - val_accuracy: 0.0579 - lr: 0.0010
# Epoch 475/500
# 11/16 [===================>..........] - ETA: 0s - loss: 0.0418 - accuracy: 0.0085    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0387 - accuracy: 0.0103 - val_loss: 0.5694 - val_accuracy: 0.0496 - lr: 0.0010
# Epoch 476/500
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0371 - accuracy: 0.0168    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0401 - accuracy: 0.0145 - val_loss: 0.5570 - val_accuracy: 0.0661 - lr: 0.0010
# Epoch 477/500
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0427 - accuracy: 0.0120    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0450 - accuracy: 0.0103 - val_loss: 0.5570 - val_accuracy: 0.0661 - lr: 0.0010
# Epoch 478/500
# 12/16 [=====================>........] - ETA: 0s - loss: 0.0475 - accuracy: 0.0156    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0466 - accuracy: 0.0124 - val_loss: 0.5589 - val_accuracy: 0.0661 - lr: 0.0010
# Epoch 479/500
# 12/16 [=====================>........] - ETA: 0s - loss: 0.0336 - accuracy: 0.0104    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0392 - accuracy: 0.0103 - val_loss: 0.5580 - val_accuracy: 0.0661 - lr: 0.0010
# Epoch 480/500
#  9/16 [===============>..............] - ETA: 0s - loss: 0.0333 - accuracy: 0.0139    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 8ms/step - loss: 0.0399 - accuracy: 0.0145 - val_loss: 0.5546 - val_accuracy: 0.0661 - lr: 0.0010
# Epoch 481/500
# 12/16 [=====================>........] - ETA: 0s - loss: 0.0432 - accuracy: 0.0130    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0441 - accuracy: 0.0103 - val_loss: 0.5525 - val_accuracy: 0.0661 - lr: 0.0010
# Epoch 482/500
# 12/16 [=====================>........] - ETA: 0s - loss: 0.0390 - accuracy: 0.0156WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0382 - accuracy: 0.0124 - val_loss: 0.5527 - val_accuracy: 0.0661 - lr: 0.0010
# Epoch 483/500
# 12/16 [=====================>........] - ETA: 0s - loss: 0.0402 - accuracy: 0.0156    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0423 - accuracy: 0.0124 - val_loss: 0.5724 - val_accuracy: 0.0661 - lr: 0.0010
# Epoch 484/500
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0477 - accuracy: 0.0168    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0474 - accuracy: 0.0165 - val_loss: 0.5827 - val_accuracy: 0.0579 - lr: 0.0010
# Epoch 485/500
# 12/16 [=====================>........] - ETA: 0s - loss: 0.0400 - accuracy: 0.0156    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0388 - accuracy: 0.0124 - val_loss: 0.5626 - val_accuracy: 0.0661 - lr: 0.0010
# Epoch 486/500
# 12/16 [=====================>........] - ETA: 0s - loss: 0.0384 - accuracy: 0.0078WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0411 - accuracy: 0.0103 - val_loss: 0.5819 - val_accuracy: 0.0579 - lr: 0.0010
# Epoch 487/500
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0502 - accuracy: 0.0120    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0491 - accuracy: 0.0145 - val_loss: 0.5709 - val_accuracy: 0.0579 - lr: 0.0010
# Epoch 488/500
# 12/16 [=====================>........] - ETA: 0s - loss: 0.0439 - accuracy: 0.0130    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0440 - accuracy: 0.0103 - val_loss: 0.5541 - val_accuracy: 0.0579 - lr: 0.0010
# Epoch 489/500
# 12/16 [=====================>........] - ETA: 0s - loss: 0.0405 - accuracy: 0.0130    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0397 - accuracy: 0.0103 - val_loss: 0.5541 - val_accuracy: 0.0661 - lr: 0.0010
# Epoch 490/500
# 10/16 [=================>............] - ETA: 0s - loss: 0.0443 - accuracy: 0.0125    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 8ms/step - loss: 0.0422 - accuracy: 0.0124 - val_loss: 0.5562 - val_accuracy: 0.0661 - lr: 0.0010
# Epoch 491/500
# 12/16 [=====================>........] - ETA: 0s - loss: 0.0448 - accuracy: 0.0104    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0461 - accuracy: 0.0103 - val_loss: 0.5598 - val_accuracy: 0.0579 - lr: 0.0010
# Epoch 492/500
# 12/16 [=====================>........] - ETA: 0s - loss: 0.0421 - accuracy: 0.0130    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0415 - accuracy: 0.0103 - val_loss: 0.5550 - val_accuracy: 0.0579 - lr: 0.0010
# Epoch 493/500
# 12/16 [=====================>........] - ETA: 0s - loss: 0.0379 - accuracy: 0.0130    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0387 - accuracy: 0.0103 - val_loss: 0.5540 - val_accuracy: 0.0661 - lr: 0.0010
# Epoch 494/500
# 12/16 [=====================>........] - ETA: 0s - loss: 0.0364 - accuracy: 0.0130WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0380 - accuracy: 0.0103 - val_loss: 0.5501 - val_accuracy: 0.0579 - lr: 0.0010
# Epoch 495/500
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0375 - accuracy: 0.0144    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0398 - accuracy: 0.0124 - val_loss: 0.5508 - val_accuracy: 0.0661 - lr: 0.0010
# Epoch 496/500
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0439 - accuracy: 0.0096    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0449 - accuracy: 0.0103 - val_loss: 0.5495 - val_accuracy: 0.0579 - lr: 0.0010
# Epoch 497/500
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0384 - accuracy: 0.0096    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0429 - accuracy: 0.0103 - val_loss: 0.5564 - val_accuracy: 0.0496 - lr: 0.0010
# Epoch 498/500
# 12/16 [=====================>........] - ETA: 0s - loss: 0.0378 - accuracy: 0.0104    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0366 - accuracy: 0.0103 - val_loss: 0.5636 - val_accuracy: 0.0496 - lr: 0.0010
# Epoch 499/500
# 12/16 [=====================>........] - ETA: 0s - loss: 0.0389 - accuracy: 0.0104    WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0410 - accuracy: 0.0103 - val_loss: 0.5681 - val_accuracy: 0.0496 - lr: 0.0010
# Epoch 500/500
# 12/16 [=====================>........] - ETA: 0s - loss: 0.0402 - accuracy: 0.0156WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0388 - accuracy: 0.0124 - val_loss: 0.5640 - val_accuracy: 0.0579 - lr: 0.0010
# The 10th iteration is run

# %%
risk = dcdr_model.predict_cdf(X_RBF_pred,pred_lim=[12,12],ngrid=1)

# 모형별 예측밴드 그려보는 작업이 있으면 좋을것 같습니다.
# Out:
# 241/241 [==============================] - 1s 3ms/step
#  26/241 [==>...........................] - ETA: 0s
# 241/241 [==============================] - 1s 2ms/step
# 241/241 [==============================] - 1s 2ms/step
# 241/241 [==============================] - 1s 2ms/step
# 241/241 [==============================] - 1s 5ms/step
# 241/241 [==============================] - 1s 4ms/step
# 241/241 [==============================] - 1s 2ms/step
# 241/241 [==============================] - 1s 2ms/step
# 241/241 [==============================] - 1s 2ms/step
# 241/241 [==============================] - 1s 4ms/step

# %%
riskdf=pd.DataFrame(risk)
riskdf.to_csv('C:\git\DeepKriging/risk_pred.csv')
